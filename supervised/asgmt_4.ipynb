# %% [markdown]
# <a href="https://colab.research.google.com/github/AnasGamal/cs431-ml-models/blob/main/supervised/asgmt_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
